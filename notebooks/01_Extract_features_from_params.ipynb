# %% [markdown]
# # Extract features from params
#
# This notebook contains (ugly) code for parsing and structuring features from the "params" original feature.
# Multiple features are contained there, and some require some heuristics / 'bussiness' logic to properly transform.
# This transformation is time-consuming, may contain errors, and expanding the number of features too much would hurt explainability, and may create overfitting.
#
# However, this exploratory notebook would be used for defining an (optional) loading_data feature, which would also include this new features.
#
# ## Load the dataset

# %%
import pandas as pd
df = pd.read_csv('../data/real_estate_ads_2022_10.csv')
raw_df = df.copy()
df
# Out:
#              id     market         created_at_first               updated_at  \
# 0      58668640  secondary  2019-04-09 16:12:54.000  2019-04-15 18:54:38.000
# 1      58887800  secondary  2019-04-25 17:20:01.000  2019-05-27 11:36:14.000
# 2      55129916  secondary  2018-08-02 16:40:35.000  2021-11-28 01:56:53.000
# 3      60011531  secondary  2019-12-05 12:45:49.000  2020-01-15 16:05:42.000
# 4      60096194  secondary  2020-01-10 14:53:19.000  2020-02-13 15:25:07.000
# ...         ...        ...                      ...                      ...
# 73640  59477668  secondary  2019-07-16 22:38:08.000  2019-10-14 23:01:42.000
# 73641  59479003  secondary  2019-07-17 11:18:30.000  2019-08-07 14:22:54.000
# 73642  59474988  secondary  2019-07-16 13:40:35.000  2019-07-23 00:30:42.000
# 73643  59428272  secondary  2019-07-03 20:50:27.000  2022-06-17 17:14:34.000
# 73644  59437422  secondary  2019-07-05 23:17:45.000  2019-08-04 23:24:06.000
#
#        district_lon  district_lat  \
# 0          16.90502      52.41180
# 1          16.87466      52.41572
# 2          16.90502      52.41180
# 3          16.87466      52.41572
# 4          16.87466      52.41572
# ...             ...           ...
# 73640      16.94080      52.38356
# 73641      16.94080      52.38356
# 73642      16.90590      52.36596
# 73643      16.94080      52.38356
# 73644      16.93625      52.42658
#
#                                                    title  \
# 0               Mieszkanie z potencjałem. Rynek Jeżycki.
# 1                                     Okazja Jeżyce!!!!!
# 2      **Okazja * 60,1m2 * 3 pokoje * poddasze * Jeży...
# 3              Mieszkanie 2-pokojowe, Ogrody, Kampus Uam
# 4                                        Jeżyce 2 pokoje
# ...                                                  ...
# 73640         Poznań - Rataje idealny układ pomieszczeń.
# 73641       2 pokojowe z balkonem RATAJE os. Piastowskie
# 73642  Inwestycyjne 2 niezależne pokoje, do wykończenia.
# 73643  Przestronna kawalerka z dużym tarasem Chartowo...
# 73644  Sprzedam 3 pokojowe mieszkanie, Poznań - Winog...
#
#                                              description  \
# 0      <p>Zapraszam do zakupu mieszkania zlokalizowan...
# 1      <p>Polecam na sprzedaż mieszkanie kawalerka o ...
# 2      <p>  **Przestronne mieszkanie 3 pokojowe * na ...
# 3      <p>Serdecznie zapraszam do zapoznania się z of...
# 4      <p>Polecam na sprzedaż mieszkanie z komórka lo...
# ...                                                  ...
# 73640  <p>Drodzy Państwo,</p>\r\n<p>Zapraszam do zapo...
# 73641  <p>Polecam na sprzedaż mieszkanie 2 pokojowe u...
# 73642  <p>Na sprzedaż przestronne mieszkanie położone...
# 73643  <p>Kontakt w sprawie oferty - Katarzyna Piotro...
# 73644  <p>Sprzedam 3 pokojowe zadbane mieszkanie usyt...
#
#                                                   params     price no_rooms  \
# 0      price<=>price<br>price<=>260000<br>price[curre...  260000.0        2
# 1      price<=>price<br>price<=>155000<br>price[curre...  155000.0        1
# 2      price<=>price<br>price<=>280000<br>price[curre...  280000.0        3
# 3      price<=>price<br>price<=>339000<br>price[curre...  339000.0        2
# 4      price<=>price<br>price<=>325000<br>price[curre...  325000.0        2
# ...                                                  ...       ...      ...
# 73640  price<=>price<br>price<=>347000<br>price[curre...  347000.0        3
# 73641  price<=>price<br>price<=>299000<br>price[curre...  299000.0        2
# 73642  price<=>price<br>price<=>270000<br>price[curre...  270000.0        2
# 73643  price<=>price<br>price<=>229000<br>price[curre...  229000.0        1
# 73644  price<=>price<br>price<=>399000<br>price[curre...  399000.0        3
#
#            m  price_per_m    map_lon    map_lat
# 0      51.00      5098.04  16.896592  52.410150
# 1      26.00      5961.54  16.904410  52.411919
# 2      60.10      4658.90  16.899310  52.413357
# 3      47.00      7212.77  16.883608  52.410662
# 4      44.00      7386.36  16.890796  52.412308
# ...      ...          ...        ...        ...
# 73640  47.00      7382.98  16.955818  52.389898
# 73641  43.70      6842.11  16.947615  52.392968
# 73642  45.32      5957.63  16.904862  52.369679
# 73643  36.30      6308.54  16.980725  52.389168
# 73644  67.00      5955.22  16.935134  52.435895
#
# [73645 rows x 15 columns]

# %% [markdown]
# ## Identify all given parameters

# %%
params = [[ll.split("<=>")[0] for ll in param.split("<br>")] for param in df['params'].tolist()]
print(f"Are all the list containing the same keys? {all([set(params[0]) == set(param) for param in params])}")
# Out:
# Are all the list containing the same keys? False

# %%
# Get the unique parameters
unique_params = {param for param_list in params for param in param_list}
unique_params
# Out:
# {'access_types',
#  'build_year',
#  'building_floors_num',
#  'building_material',
#  'building_ownership',
#  'building_type',
#  'construction_status',
#  'equipment_types',
#  'extras_types',
#  'fence_types',
#  'floor_no',
#  'floors_num',
#  'free_from',
#  'garret_type',
#  'heating',
#  'heating_types',
#  'is_bungalow',
#  'location',
#  'm',
#  'market',
#  'media_types',
#  'price',
#  'price[currency]',
#  'price_per_m',
#  'recreational',
#  'remote_services',
#  'rent',
#  'rent[currency]',
#  'roof_type',
#  'roofing',
#  'rooms_num',
#  'security_types',
#  'terrain_area',
#  'vicinity_types',
#  'windows_type'}

# %% [markdown]
# ## Define regex for each param

# %%
import re
def get_params(param_list, param):
    param = re.escape(param)
    pattern = re.compile(f'{param}<=>(.*?)<br>')
    currencies = [re.findall(pattern, t) for t in df["params"].tolist()]

    return currencies
currencies = get_params(params, "price[currency]")

# %% [markdown]
# ## Get new features from params

# %%
params = df["params"].tolist()
for param in unique_params:
    currencies = get_params(params, param)
    df[f"param_{param}"] = currencies

# %%
currencies = get_params(params, "price[currency]")
print(currencies)
# Out:
# [['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['PLN'], ['P ...

# %%
params
# Out:
# ['price<=>price<br>price<=>260000<br>price[currency]<=>PLN<br>m<=>51<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_3<br>building_floors_num<=>3<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=><br>build_year<=>1920<br>construction_status<=>to_renovation<br>rent<=>price<br>rent<=>110<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>basement<br>price_per_m<=>5098.04',
#  'price<=>price<br>price<=>155000<br>price[currency]<=>PLN<br>m<=>26<br>rooms_num<=>1<br>market<=>secondary<br>building_type<=><br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>5961.54',
#  'price<=>price<br>price<=>280000<br>price[currency]<=>PLN<br>m<=>60.1<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>wooden<br>heating<=>electrical<br>build_year<=>1980<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>168<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>4658.9',
#  'price<=>price<br>price<=>339000<br>price[currency]<=>PLN<br>m<=>47<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=><br>heating<=>urban<br>build_year<=>1965<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>457.65<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>basement<->separate_kitchen<->usable_room<br>price_per_m<=>7212.77',
#  'price<=>price<br>price<=>325000<br>price[currency]<=>PLN<br>m<=>44<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=><br>floor_no<=>floor_3<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>1936<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>7386.36',
#  'price<=>price<br>price<=>574459<br>price[currency]<=>PLN<br>remote_services<=><br>m<=>67.33<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_3<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=><br>heating<=>urban<br>build_year<=>1840<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>8531.99',
#  'price<=>price<br>price<=>419178<br>price[currency]<=>PLN<br>m<=>49<br>rooms_num<=>2<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>8554.65',
#  'price<=>price<br>price<=>635000<br>price[currency]<=>PLN<br>m<=>63<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=><br>floor_no<=>ground_floor<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2018<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>10079.37',
#  'price<=>price<br>price<=>415049<br>price[currency]<=>PLN<br>m<=>42.03<br>rooms_num<=>2<br>market<=>primary<br>building_type<=>apartment<br>floor_no<=>floor_3<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2020<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>internet<br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->garage<->lift<br>price_per_m<=>9875.07',
#  'price<=>price<br>price<=>574825<br>price[currency]<=>PLN<br>m<=>62.29<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=>plastic<br>heating<=><br>build_year<=>2020<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->garage<br>price_per_m<=>9228.21',
#  'price<=>price<br>price<=>359000<br>price[currency]<=>PLN<br>m<=>52<br>remote_services<=>1<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1955<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>400<br>rent[currency]<=>PLN<br>building_ownership<=>co_operative_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=>closed_area<->entryphone<br>equipment_types<=>fridge<->furniture<->oven<->stove<->washing_machine<br>extras_types<=>balcony<->basement<->garage<->separate_kitchen<br>price_per_m<=>6903.85',
#  'price<=>price<br>price<=>574825<br>price[currency]<=>PLN<br>m<=>62.29<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=>plastic<br>heating<=><br>build_year<=>2020<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>700<br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=>2020-12-31<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<br>price_per_m<=>9228.21',
#  'price<=>price<br>price<=>266570<br>price[currency]<=>PLN<br>m<=>28.06<br>rooms_num<=>1<br>market<=>primary<br>building_type<=>tenement<br>floor_no<=>floor_4<br>building_floors_num<=>6<br>building_material<=>breezeblock<br>windows_type<=><br>heating<=><br>build_year<=>2020<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->lift<br>price_per_m<=>9500',
#  'price<=>price<br>price<=>375000<br>price[currency]<=>PLN<br>m<=>61.7<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1957<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>580<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->basement<->separate_kitchen<br>price_per_m<=>6077.8',
#  'price<=>price<br>price<=>364848<br>price[currency]<=>PLN<br>m<=>41.46<br>rooms_num<=>2<br>market<=>primary<br>building_type<=>tenement<br>floor_no<=>floor_5<br>building_floors_num<=>6<br>building_material<=>breezeblock<br>windows_type<=><br>heating<=><br>build_year<=>2020<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>8800',
#  'price<=>price<br>price<=>421168.5<br>price[currency]<=>PLN<br>m<=>48.69<br>rooms_num<=>2<br>market<=>primary<br>building_type<=>tenement<br>floor_no<=>floor_5<br>building_floors_num<=>6<br>building_material<=>breezeblock<br>windows_type<=><br>heating<=><br>build_year<=>2020<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>8650',
#  'price<=>price<br>price<=>223600<br>price[currency]<=>PLN<br>m<=>26<br>rooms_num<=>1<br>market<=>primary<br>building_type<=>tenement<br>floor_no<=>floor_1<br>building_floors_num<=>6<br>building_material<=>breezeblock<br>windows_type<=><br>heating<=><br>build_year<=>2020<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->lift<br>price_per_m<=>8600',
#  'price<=>price<br>price<=>337000<br>price[currency]<=>PLN<br>m<=>39.57<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2018<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->garage<->lift<br>price_per_m<=>8516.55',
#  'price<=>price<br>price<=>365820<br>price[currency]<=>PLN<br>m<=>46.9<br>rooms_num<=>4<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2002<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=>0<br>security_types<=>0<br>equipment_types<=>0<br>extras_types<=>balcony<->separate_kitchen<br>price_per_m<=>7800',
#  'price<=>price<br>price<=>301155<br>price[currency]<=>PLN<br>m<=>35.43<br>rooms_num<=>2<br>market<=>primary<br>building_type<=>tenement<br>floor_no<=>floor_5<br>building_floors_num<=>6<br>building_material<=>breezeblock<br>windows_type<=><br>heating<=><br>build_year<=>2020<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>8500',
#  'price<=>price<br>price<=>379794<br>price[currency]<=>PLN<br>m<=>50.15<br>rooms_num<=>3<br>market<=>primary<br>building_type<=>loft<br>floor_no<=>floor_4<br>building_floors_num<=><br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=><br>build_year<=>2018<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=>2019-02-04<br>media_types<=>internet<br>security_types<=>0<br>equipment_types<=>0<br>extras_types<=>0<br>price_per_m<=>7573.16',
#  'price<=>price<br>price<=>279000<br>price[currency]<=>PLN<br>m<=>44.5<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>ground_floor<br>building_floors_num<=>2<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>other<br>build_year<=>1959<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>500<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>basement<->separate_kitchen<br>price_per_m<=>6269.66',
#  'price<=>price<br>price<=>397350<br>price[currency]<=>PLN<br>m<=>44.15<br>rooms_num<=>2<br>market<=>primary<br>building_type<=>ribbon<br>floor_no<=>floor_2<br>building_floors_num<=>5<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2019<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=>phone<br>security_types<=>entryphone<br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>9000',
#  'price<=>price<br>price<=>349000<br>price[currency]<=>PLN<br>m<=>64<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_8<br>building_floors_num<=>10<br>building_material<=>concrete_plate<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1977<br>construction_status<=>to_renovation<br>rent<=>price<br>rent<=>600<br>rent[currency]<=>PLN<br>building_ownership<=>co_operative_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<br>security_types<=><br>equipment_types<=><br>extras_types<=>basement<->lift<br>price_per_m<=>5453.13',
#  'price<=>price<br>price<=>395000<br>price[currency]<=>PLN<br>m<=>43.69<br>rooms_num<=>2<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_5<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=><br>heating<=>urban<br>build_year<=>2018<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=>entryphone<br>equipment_types<=><br>extras_types<=>balcony<->garage<->lift<br>price_per_m<=>9040.97',
#  'price<=>price<br>price<=>276000<br>price[currency]<=>PLN<br>m<=>49.3<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_3<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1960<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>580<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=>2018-12-20<br>media_types<=>cable-television<->internet<br>security_types<=>anti_burglary_door<->entryphone<br>equipment_types<=>furniture<br>extras_types<=>basement<->garage<->separate_kitchen<br>price_per_m<=>5598.38',
#  'price<=>price<br>price<=>155000<br>price[currency]<=>PLN<br>m<=>26<br>rooms_num<=>1<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_4<br>building_floors_num<=><br>building_material<=>brick<br>windows_type<=>wooden<br>heating<=>gas<br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>160<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>0<br>security_types<=>closed_area<->entryphone<br>equipment_types<=>fridge<->furniture<->stove<->washing_machine<br>extras_types<=>basement<->usable_room<br>price_per_m<=>5961.54',
#  'price<=>price<br>price<=>425000<br>price[currency]<=>PLN<br>m<=>69.59<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>ground_floor<br>building_floors_num<=>3<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2011<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>500<br>rent[currency]<=>PLN<br>building_ownership<=>co_operative_ownership_with_a_land_and_mortgage_registe<br>free_from<=>2022-01-01<br>media_types<=>cable-television<->internet<->phone<br>security_types<=>closed_area<->entryphone<->monitoring<->roller_shutters<br>equipment_types<=>dishwasher<->fridge<->furniture<->oven<->stove<->tv<->washing_machine<br>extras_types<=>balcony<->garage<->lift<->terrace<->usable_room<br>price_per_m<=>6107.2',
#  'price<=>price<br>price<=>489000<br>price[currency]<=>PLN<br>m<=>52<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=><br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>9403.85',
#  'price<=>price<br>price<=>349000<br>price[currency]<=>PLN<br>m<=>38<br>remote_services<=><br>rooms_num<=>1<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>ground_floor<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=><br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>9184.21',
#  'price<=>price<br>price<=>1119000<br>price[currency]<=>PLN<br>m<=>77.53<br>remote_services<=><br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>apartment<br>floor_no<=>floor_6<br>building_floors_num<=>7<br>building_material<=>brick<br>windows_type<=><br>heating<=>urban<br>build_year<=>2016<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>857<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=>monitoring<br>equipment_types<=><br>extras_types<=>garage<->lift<br>price_per_m<=>14433.12',
#  'price<=>price<br>price<=>465000<br>price[currency]<=>PLN<br>m<=>58<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1958<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>800<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=>anti_burglary_door<->entryphone<br>equipment_types<=>dishwasher<->fridge<->furniture<->oven<->stove<->washing_machine<br>extras_types<=>balcony<->basement<->separate_kitchen<br>price_per_m<=>8017.24',
#  'price<=>price<br>price<=>277000<br>price[currency]<=>PLN<br>m<=>27<br>remote_services<=><br>rooms_num<=>1<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_4<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2022<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>10259.26',
#  'price<=>price<br>price<=>279000<br>price[currency]<=>PLN<br>m<=>27.5<br>remote_services<=><br>rooms_num<=>1<br>market<=>secondary<br>building_type<=><br>floor_no<=>floor_3<br>building_floors_num<=>9<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>10145.45',
#  'price<=>price<br>price<=>459000<br>price[currency]<=>PLN<br>m<=>32.72<br>remote_services<=>1<br>rooms_num<=>1<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_5<br>building_floors_num<=>5<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2015<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>320<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<br>security_types<=>anti_burglary_door<->entryphone<->monitoring<br>equipment_types<=>dishwasher<->fridge<->oven<->stove<->washing_machine<br>extras_types<=>balcony<->lift<->terrace<br>price_per_m<=>14028.12',
#  'price<=>price<br>price<=>990000<br>price[currency]<=>PLN<br>m<=>60.5<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>apartment<br>floor_no<=>floor_5<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2021<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>700<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=>2022-10-03<br>media_types<=>internet<br>security_types<=>closed_area<->entryphone<br>equipment_types<=>furniture<br>extras_types<=>balcony<->garage<->lift<br>price_per_m<=>16363.64',
#  'price<=>price<br>price<=>285000<br>price[currency]<=>PLN<br>m<=>33.15<br>remote_services<=><br>rooms_num<=>1<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>ground_floor<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1958<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>co_operative_ownership<br>free_from<=><br>media_types<=><br>security_types<=>entryphone<br>equipment_types<=><br>extras_types<=>basement<br>price_per_m<=>8597.29',
#  'price<=>price<br>price<=>345000<br>price[currency]<=>PLN<br>m<=>42.5<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1960<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>350<br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=>0<br>equipment_types<=>furniture<br>extras_types<=>balcony<->separate_kitchen<br>price_per_m<=>8117.65',
#  'price<=>price<br>price<=>1519452<br>price[currency]<=>PLN<br>m<=>127.9<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_5<br>building_floors_num<=>5<br>building_material<=>brick<br>windows_type<=><br>heating<=>urban<br>build_year<=>2018<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<->terrace<br>price_per_m<=>11880',
#  'price<=>price<br>price<=>339000<br>price[currency]<=>PLN<br>m<=>35<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=><br>floor_no<=>floor_4<br>building_floors_num<=>8<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2016<br>construction_status<=><br>rent<=>price<br>rent<=>330<br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>9685.71',
#  'price<=>price<br>price<=>282000<br>price[currency]<=>PLN<br>m<=>39<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>1960<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>7230.77',
#  'price<=>price<br>price<=>235600<br>price[currency]<=>PLN<br>m<=>24.8<br>rooms_num<=>1<br>market<=>primary<br>building_type<=>tenement<br>floor_no<=>floor_4<br>building_floors_num<=>6<br>building_material<=>breezeblock<br>windows_type<=><br>heating<=><br>build_year<=>2020<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>9500',
#  'price<=>price<br>price<=>296999<br>price[currency]<=>PLN<br>m<=>30.15<br>remote_services<=><br>rooms_num<=>1<br>market<=>primary<br>building_type<=>block<br>floor_no<=>floor_4<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=>2023-02-28<br>media_types<=>internet<br>security_types<=>entryphone<->monitoring<br>equipment_types<=><br>extras_types<=>balcony<->garage<->lift<br>price_per_m<=>9850.71',
#  'price<=>price<br>price<=>429000<br>price[currency]<=>PLN<br>m<=>49<br>remote_services<=><br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=><br>heating<=>urban<br>build_year<=>1960<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<br>price_per_m<=>8755.1',
#  'price<=>price<br>price<=>990000<br>price[currency]<=>PLN<br>m<=>110<br>remote_services<=>1<br>rooms_num<=>4<br>market<=>secondary<br>building_type<=>apartment<br>floor_no<=>floor_2<br>building_floors_num<=>2<br>building_material<=><br>windows_type<=><br>heating<=>urban<br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=>closed_area<->entryphone<->monitoring<->roller_shutters<br>equipment_types<=>dishwasher<->fridge<->furniture<->oven<->stove<->tv<->washing_machine<br>extras_types<=>air_conditioning<->balcony<->basement<->garage<->separate_kitchen<->terrace<->usable_room<br>price_per_m<=>9000',
#  'price<=>price<br>price<=>610000<br>price[currency]<=>PLN<br>m<=>67.36<br>remote_services<=><br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_3<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1956<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>640<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<br>security_types<=>anti_burglary_door<->closed_area<->entryphone<br>equipment_types<=>dishwasher<->fridge<->oven<->stove<br>extras_types<=>basement<->garage<->separate_kitchen<br>price_per_m<=>9055.82',
#  'price<=>price<br>price<=>860000<br>price[currency]<=>PLN<br>m<=>82.6<br>remote_services<=><br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>apartment<br>floor_no<=>floor_1<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2009<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=>2022-04-19<br>media_types<=><br>security_types<=>anti_burglary_door<->entryphone<br>equipment_types<=>furniture<br>extras_types<=>garage<->lift<br>price_per_m<=>10411.62',
#  'price<=>price<br>price<=>349000<br>price[currency]<=>PLN<br>m<=>35<br>remote_services<=><br>rooms_num<=>2<br>market<=>primary<br>building_type<=>apartment<br>floor_no<=>floor_1<br>building_floors_num<=>5<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2022<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=>cable-television<->internet<br>security_types<=>entryphone<->monitoring<br>equipment_types<=>0<br>extras_types<=>balcony<->basement<->garage<->lift<br>price_per_m<=>9971.43',
#  'price<=>price<br>price<=>1150000<br>price[currency]<=>PLN<br>m<=>93<br>remote_services<=><br>rooms_num<=>4<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=>plastic<br>heating<=>gas<br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=>cable-television<br>security_types<=>entryphone<br>equipment_types<=>furniture<br>extras_types<=>separate_kitchen<br>price_per_m<=>12365.59',
#  'price<=>price<br>price<=>359000<br>price[currency]<=>PLN<br>m<=>38<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=><br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>separate_kitchen<br>price_per_m<=>9447.37',
#  'price<=>price<br>price<=>430000<br>price[currency]<=>PLN<br>m<=>46.35<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>apartment<br>floor_no<=>ground_floor<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=>urban<br>build_year<=>2019<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=>anti_burglary_door<->closed_area<->entryphone<->monitoring<->roller_shutters<br>equipment_types<=>dishwasher<->fridge<->furniture<->oven<->stove<->washing_machine<br>extras_types<=>garage<->garden<->lift<->terrace<br>price_per_m<=>9277.24',
#  'price<=>price<br>price<=>625000<br>price[currency]<=>PLN<br>m<=>100<br>remote_services<=>1<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>gas<br>build_year<=>1950<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>200<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<br>security_types<=>closed_area<br>equipment_types<=>0<br>extras_types<=>garage<br>price_per_m<=>6250',
#  'price<=>price<br>price<=>315900<br>price[currency]<=>PLN<br>m<=>29<br>remote_services<=>1<br>rooms_num<=>1<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>garret<br>building_floors_num<=><br>building_material<=>brick<br>windows_type<=><br>heating<=>urban<br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>290<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<br>security_types<=>anti_burglary_door<->closed_area<->entryphone<br>equipment_types<=>fridge<->furniture<->stove<->washing_machine<br>extras_types<=>0<br>price_per_m<=>10893.1',
#  'price<=>price<br>price<=>276000<br>price[currency]<=>PLN<br>m<=>38.1<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_4<br>building_floors_num<=>10<br>building_material<=>other<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>co_operative_ownership<br>free_from<=><br>media_types<=>0<br>security_types<=>0<br>equipment_types<=>fridge<->furniture<->oven<->washing_machine<br>extras_types<=>balcony<->basement<->lift<br>price_per_m<=>7244.09',
#  'price<=>price<br>price<=>290000<br>price[currency]<=>PLN<br>m<=>27<br>rooms_num<=>1<br>market<=>secondary<br>building_type<=><br>floor_no<=>floor_5<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>10740.74',
#  'price<=>price<br>price<=>445000<br>price[currency]<=>PLN<br>m<=>56<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>apartment<br>floor_no<=>floor_1<br>building_floors_num<=>5<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2009<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>internet<br>security_types<=>monitoring<br>equipment_types<=><br>extras_types<=>balcony<->lift<->separate_kitchen<br>price_per_m<=>7946.43',
#  'price<=>price<br>price<=>258152<br>price[currency]<=>PLN<br>m<=>28.06<br>rooms_num<=>1<br>market<=>primary<br>building_type<=>tenement<br>floor_no<=>floor_2<br>building_floors_num<=>6<br>building_material<=>breezeblock<br>windows_type<=><br>heating<=><br>build_year<=>2020<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->lift<br>price_per_m<=>9200',
#  'price<=>price<br>price<=>235000<br>price[currency]<=>PLN<br>m<=>38<br>rooms_num<=>1<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>ground_floor<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>350<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=>2019-04-30<br>media_types<=>cable-television<->internet<br>security_types<=>0<br>equipment_types<=>furniture<->oven<->stove<->washing_machine<br>extras_types<=>basement<->separate_kitchen<br>price_per_m<=>6184.21',
#  'price<=>price<br>price<=>310000<br>price[currency]<=>PLN<br>m<=>37<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>220<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=>2019-04-24<br>media_types<=>cable-television<->internet<br>security_types<=>closed_area<->entryphone<br>equipment_types<=>dishwasher<->oven<->stove<br>extras_types<=>balcony<->basement<br>price_per_m<=>8378.38',
#  'price<=>price<br>price<=>365000<br>price[currency]<=>PLN<br>m<=>59.1<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=>other<br>windows_type<=>plastic<br>heating<=>other<br>build_year<=>1990<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=>phone<br>security_types<=>closed_area<->monitoring<br>equipment_types<=><br>extras_types<=>balcony<->basement<br>price_per_m<=>6175.97',
#  'price<=>price<br>price<=>345000<br>price[currency]<=>PLN<br>m<=>39.57<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2018<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->garage<->lift<br>price_per_m<=>8718.73',
#  'price<=>price<br>price<=>265000<br>price[currency]<=>PLN<br>m<=>51<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_3<br>building_floors_num<=>3<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=><br>build_year<=>1920<br>construction_status<=>to_renovation<br>rent<=>price<br>rent<=>110<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>basement<br>price_per_m<=>5196.08',
#  'price<=>price<br>price<=>276000<br>price[currency]<=>PLN<br>m<=>38.1<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_4<br>building_floors_num<=>10<br>building_material<=>other<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>0<br>security_types<=>0<br>equipment_types<=>fridge<->furniture<->oven<->stove<->washing_machine<br>extras_types<=>balcony<->basement<->lift<br>price_per_m<=>7244.09',
#  'price<=>price<br>price<=>319000<br>price[currency]<=>PLN<br>m<=>48<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=><br>floor_no<=>ground_floor<br>building_floors_num<=>9<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2007<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>6645.83',
#  'price<=>price<br>price<=>355000<br>price[currency]<=>PLN<br>m<=>42.16<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_6<br>building_floors_num<=>6<br>building_material<=>other<br>windows_type<=>wooden<br>heating<=>urban<br>build_year<=>2002<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>430<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>8420.3',
#  'price<=>price<br>price<=>348796.8<br>price[currency]<=>PLN<br>m<=>29.36<br>rooms_num<=>1<br>market<=>primary<br>building_type<=>apartment<br>floor_no<=>floor_1<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=><br>heating<=>urban<br>build_year<=>2019<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=>anti_burglary_door<->entryphone<->roller_shutters<br>equipment_types<=>0<br>extras_types<=>balcony<->garage<->lift<->usable_room<br>price_per_m<=>11880',
#  'price<=>price<br>price<=>329000<br>price[currency]<=>PLN<br>m<=>47.8<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2001<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2019-03-19<br>media_types<=><br>security_types<=>entryphone<br>equipment_types<=><br>extras_types<=>balcony<->lift<br>price_per_m<=>6882.85',
#  'price<=>price<br>price<=>375000<br>price[currency]<=>PLN<br>m<=>65<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=><br>floor_no<=><br>building_floors_num<=><br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>5769.23',
#  'price<=>price<br>price<=>369000<br>price[currency]<=>PLN<br>m<=>66<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=><br>floor_no<=>floor_higher_10<br>building_floors_num<=>16<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1995<br>construction_status<=><br>rent<=>price<br>rent<=>800<br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->basement<->lift<->separate_kitchen<br>price_per_m<=>5590.91',
#  'price<=>price<br>price<=>439000<br>price[currency]<=>PLN<br>m<=>71.53<br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>1<br>building_material<=><br>windows_type<=>plastic<br>heating<=>other<br>build_year<=>2019<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>6137.29',
#  'price<=>price<br>price<=>349000<br>price[currency]<=>PLN<br>m<=>42<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_3<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=><br>build_year<=>1910<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>basement<br>price_per_m<=>8309.52',
#  'price<=>price<br>price<=>229000<br>price[currency]<=>PLN<br>remote_services<=><br>m<=>30.58<br>rooms_num<=>1<br>market<=>primary<br>building_type<=>apartment<br>floor_no<=>floor_2<br>building_floors_num<=>6<br>building_material<=>brick<br>windows_type<=><br>heating<=>urban<br>build_year<=>2019<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>280<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->lift<br>price_per_m<=>7488.55',
#  'price<=>price<br>price<=>419000<br>price[currency]<=>PLN<br>m<=>53<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>7<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>1960<br>construction_status<=><br>rent<=>price<br>rent<=>450<br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->basement<->lift<br>price_per_m<=>7905.66',
#  'price<=>price<br>price<=>341000<br>price[currency]<=>PLN<br>m<=>40<br>rooms_num<=>2<br>market<=>primary<br>building_type<=>tenement<br>floor_no<=>floor_2<br>building_floors_num<=><br>building_material<=><br>windows_type<=><br>heating<=>urban<br>build_year<=><br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<br>security_types<=>entryphone<br>equipment_types<=>0<br>extras_types<=>lift<->usable_room<br>price_per_m<=>8525',
#  'price<=>price<br>price<=>429000<br>price[currency]<=>PLN<br>m<=>57.6<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_1<br>building_floors_num<=>6<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>co_operative_ownership<br>free_from<=>2019-12-06<br>media_types<=>cable-television<->internet<br>security_types<=>closed_area<->entryphone<br>equipment_types<=><br>extras_types<=>balcony<->lift<->separate_kitchen<br>price_per_m<=>7447.92',
#  'price<=>price<br>price<=>667000<br>price[currency]<=>PLN<br>m<=>99.3<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>apartment<br>floor_no<=>floor_2<br>building_floors_num<=>2<br>building_material<=>brick<br>windows_type<=>wooden<br>heating<=>gas<br>build_year<=>2012<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>350<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>0<br>security_types<=>alarm<->entryphone<->roller_shutters<br>equipment_types<=>dishwasher<->fridge<->oven<->stove<->tv<->washing_machine<br>extras_types<=>basement<->garage<->lift<->separate_kitchen<->terrace<->usable_room<br>price_per_m<=>6717.02',
#  'price<=>price<br>price<=>410000<br>price[currency]<=>PLN<br>m<=>42<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>ground_floor<br>building_floors_num<=>7<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=>350<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->lift<br>price_per_m<=>9761.9',
#  'price<=>price<br>price<=>1519452<br>price[currency]<=>PLN<br>m<=>127.9<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_5<br>building_floors_num<=>5<br>building_material<=>brick<br>windows_type<=><br>heating<=>urban<br>build_year<=>2018<br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->lift<->terrace<br>price_per_m<=>11880',
#  'price<=>price<br>price<=>826848<br>price[currency]<=>PLN<br>m<=>102.08<br>rooms_num<=>1<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>floor_3<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>wooden<br>heating<=>urban<br>build_year<=>1840<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>cable-television<->internet<->phone<br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->lift<->separate_kitchen<->usable_room<br>price_per_m<=>8100',
#  'price<=>price<br>price<=>279000<br>price[currency]<=>PLN<br>m<=>37<br>rooms_num<=>2<br>market<=>secondary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>7540.54',
#  'price<=>price<br>price<=>375000<br>price[currency]<=>PLN<br>remote_services<=><br>m<=>53<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=><br>floor_no<=>floor_2<br>building_floors_num<=>7<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>lift<br>price_per_m<=>7075.47',
#  'price<=>price<br>price<=>349000<br>price[currency]<=>PLN<br>m<=>38<br>remote_services<=><br>rooms_num<=>1<br>market<=>secondary<br>building_type<=>tenement<br>floor_no<=>ground_floor<br>building_floors_num<=>4<br>building_material<=>brick<br>windows_type<=>plastic<br>heating<=><br>build_year<=><br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>9184.21',
#  'price<=>price<br>price<=>527000<br>price[currency]<=>PLN<br>m<=>44<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_7<br>building_floors_num<=>11<br>building_material<=><br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2018<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>730<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>internet<br>security_types<=>monitoring<br>equipment_types<=><br>extras_types<=>balcony<->garage<->lift<br>price_per_m<=>11977.27',
#  'price<=>price<br>price<=>545000<br>price[currency]<=>PLN<br>m<=>57<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=><br>floor_no<=>ground_floor<br>building_floors_num<=>3<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=><br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>9561.4',
# ...
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>53.8<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>11152.42',
#  'price<=>price<br>price<=>305000<br>price[currency]<=>PLN<br>m<=>30.25<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_9<br>building_floors_num<=>10<br>building_material<=>concrete_plate<br>windows_type<=><br>heating<=><br>build_year<=><br>construction_status<=><br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>co_operative_ownership_with_a_land_and_mortgage_registe<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>balcony<->basement<->lift<br>price_per_m<=>10082.64',
#  'price<=>price<br>price<=>440000<br>price[currency]<=>PLN<br>m<=>48.9<br>remote_services<=><br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2006<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>0<br>security_types<=>0<br>equipment_types<=>0<br>extras_types<=>balcony<br>price_per_m<=>8997.96',
#  'price<=>price<br>price<=>469000<br>price[currency]<=>PLN<br>m<=>66<br>remote_services<=><br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>ground_floor<br>building_floors_num<=>2<br>building_material<=><br>windows_type<=><br>heating<=>gas<br>build_year<=>1960<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=><br>price_per_m<=>7106.06',
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>60.69<br>remote_services<=><br>rooms_num<=>4<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2023<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2023-09-15<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>9886.31',
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>54.97<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>10915.04',
#  'price<=>ondemand<br>price<=>400000<br>price[currency]<=>PLN<br>m<=>28.59<br>remote_services<=><br>rooms_num<=>1<br>market<=>primary<br>building_type<=><br>floor_no<=>ground_floor<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2023<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2023-09-15<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->terrace<->garden<->lift<br>price_per_m<=>13990.91',
#  'price<=>ondemand<br>price<=>400000<br>price[currency]<=>PLN<br>m<=>29.24<br>remote_services<=><br>rooms_num<=>1<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>13679.89',
#  'price<=>ondemand<br>price<=>700000<br>price[currency]<=>PLN<br>m<=>57.18<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>12242.04',
#  'price<=>ondemand<br>price<=>700000<br>price[currency]<=>PLN<br>m<=>67.79<br>remote_services<=><br>rooms_num<=>4<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>10326.01',
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>57.59<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>10418.48',
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>53.89<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_3<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>11133.79',
#  'price<=>ondemand<br>price<=>500000<br>price[currency]<=>PLN<br>m<=>43.89<br>remote_services<=><br>rooms_num<=>2<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_3<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>11392.12',
#  'price<=>ondemand<br>price<=>500000<br>price[currency]<=>PLN<br>m<=>43.36<br>remote_services<=><br>rooms_num<=>2<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2023<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2023-09-15<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>11531.37',
#  'price<=>ondemand<br>price<=>500000<br>price[currency]<=>PLN<br>m<=>41.96<br>remote_services<=><br>rooms_num<=>2<br>market<=>primary<br>building_type<=><br>floor_no<=>ground_floor<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2023<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2023-09-15<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->terrace<->lift<br>price_per_m<=>11916.11',
#  'price<=>price<br>price<=>449000<br>price[currency]<=>PLN<br>m<=>43.5<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=>urban<br>build_year<=>2010<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>450<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->lift<br>price_per_m<=>10321.84',
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>54.8<br>remote_services<=><br>rooms_num<=>4<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>10948.91',
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>55.1<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>10889.29',
#  'price<=>ondemand<br>price<=>700000<br>price[currency]<=>PLN<br>m<=>72.98<br>remote_services<=><br>rooms_num<=>4<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>9591.67',
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>66.24<br>remote_services<=><br>rooms_num<=>4<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_2<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2023<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2023-09-09<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>9057.97',
#  'price<=>ondemand<br>price<=>400000<br>price[currency]<=>PLN<br>m<=>39.71<br>remote_services<=><br>rooms_num<=>2<br>market<=>primary<br>building_type<=><br>floor_no<=>ground_floor<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2023<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2023-09-15<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->terrace<->lift<br>price_per_m<=>10073.03',
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>54.38<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>11033.47',
#  'price<=>price<br>price<=>429000<br>price[currency]<=>PLN<br>m<=>41.4<br>remote_services<=><br>rooms_num<=>2<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_3<br>building_floors_num<=>5<br>building_material<=><br>windows_type<=><br>heating<=>urban<br>build_year<=>2013<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=>300<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=><br>security_types<=>monitoring<br>equipment_types<=><br>extras_types<=>garage<->lift<br>price_per_m<=>10362.32',
#  'price<=>ondemand<br>price<=>800000<br>price[currency]<=>PLN<br>m<=>74.99<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->terrace<->balcony<->lift<br>price_per_m<=>10668.09',
#  'price<=>price<br>price<=>449000<br>price[currency]<=>PLN<br>m<=>51.98<br>remote_services<=>1<br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_3<br>building_floors_num<=>4<br>building_material<=>silikat<br>windows_type<=>plastic<br>heating<=>urban<br>build_year<=>2022<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=>416<br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=>2022-05-25<br>media_types<=>cable-television<->internet<->phone<br>security_types<=>alarm<->anti_burglary_door<->entryphone<br>equipment_types<=>0<br>extras_types<=>balcony<->garage<->lift<br>price_per_m<=>8637.94',
#  'price<=>ondemand<br>price<=>600000<br>price[currency]<=>PLN<br>m<=>55.07<br>remote_services<=><br>rooms_num<=>3<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_2<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>10895.22',
#  'price<=>price<br>price<=>695000<br>price[currency]<=>PLN<br>m<=>62<br>remote_services<=><br>rooms_num<=>3<br>market<=>secondary<br>building_type<=>block<br>floor_no<=>floor_1<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=>urban<br>build_year<=>2021<br>construction_status<=>ready_to_use<br>rent<=>price<br>rent<=><br>rent[currency]<=>PLN<br>building_ownership<=>full_ownership<br>free_from<=><br>media_types<=>0<br>security_types<=>entryphone<br>equipment_types<=>dishwasher<->fridge<->furniture<->oven<->stove<br>extras_types<=>balcony<->garage<->lift<br>price_per_m<=>11209.68',
#  'price<=>ondemand<br>price<=>500000<br>price[currency]<=>PLN<br>m<=>33.77<br>remote_services<=><br>rooms_num<=>2<br>market<=>primary<br>building_type<=><br>floor_no<=>floor_4<br>building_floors_num<=>4<br>building_material<=><br>windows_type<=><br>heating<=><br>build_year<=>2024<br>construction_status<=>to_completion<br>rent<=>price<br>rent<=><br>rent[currency]<=><br>building_ownership<=>full_ownership<br>free_from<=>2024-02-02<br>media_types<=><br>security_types<=><br>equipment_types<=><br>extras_types<=>garage<->balcony<->lift<br>price_per_m<=>14806.04',
#  ...]

# %%
df["param_price"]
# Out:
# 0        [price, 260000]
# 1        [price, 155000]
# 2        [price, 280000]
# 3        [price, 339000]
# 4        [price, 325000]
#               ...
# 73640    [price, 347000]
# 73641    [price, 299000]
# 73642    [price, 270000]
# 73643    [price, 229000]
# 73644    [price, 399000]
# Name: param_price, Length: 73645, dtype: object

# %% [markdown]
# ## Do a custom transformation for params_price
# Since the first key contains just the string "price"

# %%
df["param_price"] = df["param_price"].apply(lambda x: x[1] if x else None).astype("float")
print(sum(df["param_price"] != df["price"]))
df[df["param_price"]!=df["price"]][["price", "param_price"]]
# Out:
# 2064
#           price  param_price
# 15     421168.0    421168.50
# 65     348797.0    348796.80
# 107    270898.0    270898.50
# 111    374259.0    374259.42
# 117    390789.0    390789.04
# ...         ...          ...
# 73370  636134.0    636133.50
# 73407  312733.0    312732.60
# 73411  234992.0    234992.10
# 73445  267908.0    267907.50
# 73602  230648.0    230647.50
#
# [2064 rows x 2 columns]

# %% [markdown]
# We observe a mismatch between the price and param_price features, even if trying out different transformations

# %%
import math

for func in [math.floor, math.ceil, round]:
    dummy_df = pd.DataFrame()
    dummy_df["param_price"] = df["param_price"].apply(lambda x: func(x))

    print(sum(df["price"] != dummy_df["param_price"]))
# Out:
# 1790
# 1831
# 928

# %% [markdown]
# No transformation makes them equivalent. We could use a flag in between using price or param_price in training

# %%
unique_params.remove("price")

# %% [markdown]
# ## Transform the rest of the params
# ### Get the length of the different params

# %%
len_statistics = df[[f"param_{param}" for param in unique_params]].map(len).agg(['min', 'max', 'mean'])
len_statistics.T
# Out:
#                            min  max      mean
# param_market               1.0  1.0  1.000000
# param_floors_num           1.0  1.0  1.000000
# param_roofing              0.0  1.0  0.000136
# param_terrain_area         0.0  1.0  0.000136
# param_rent[currency]       1.0  1.0  1.000000
# param_windows_type         1.0  1.0  1.000000
# param_rent                 2.0  2.0  2.000000
# param_fence_types          0.0  1.0  0.000136
# param_is_bungalow          0.0  0.0  0.000000
# param_extras_types         1.0  1.0  1.000000
# param_price[currency]      1.0  1.0  1.000000
# param_building_floors_num  0.0  1.0  0.999864
# param_garret_type          0.0  1.0  0.000136
# param_remote_services      0.0  1.0  0.663833
# param_price_per_m          0.0  1.0  0.000136
# param_heating_types        0.0  1.0  0.000136
# param_building_material    1.0  1.0  1.000000
# param_build_year           1.0  1.0  1.000000
# param_building_type        1.0  1.0  1.000000
# param_free_from            1.0  1.0  1.000000
# param_m                    4.0  5.0  4.000136
# param_equipment_types      0.0  1.0  0.999864
# param_heating              0.0  1.0  0.999864
# param_construction_status  1.0  1.0  1.000000
# param_building_ownership   0.0  1.0  0.999864
# param_media_types          1.0  1.0  1.000000
# param_recreational         0.0  1.0  0.000136
# param_location             0.0  1.0  0.000136
# param_access_types         0.0  1.0  0.000136
# param_rooms_num            1.0  1.0  1.000000
# param_vicinity_types       0.0  1.0  0.000136
# param_roof_type            0.0  1.0  0.000136
# param_floor_no             0.0  1.0  0.999864
# param_security_types       1.0  1.0  1.000000

# %% [markdown]
# ### Check the params with maximum length greater than 1

# %%
len_statistics.T[len_statistics.T["max"] > 1]
# Out:
#             min  max      mean
# param_rent  2.0  2.0  2.000000
# param_m     4.0  5.0  4.000136

# %%
df["param_m"]
# Out:
# 0                   [51, 2, 3, ]
# 1                   [26, 1, 4, ]
# 2                 [60.1, 3, 4, ]
# 3                   [47, 2, 4, ]
# 4                   [44, 2, 4, ]
#                   ...
# 73640     [47, 3, 4, 2019-07-31]
# 73641             [43.7, 2, 4, ]
# 73642            [45.32, 2, 4, ]
# 73643            [36.3, 1, 18, ]
# 73644    [67, 3, 15, 2019-09-01]
# Name: param_m, Length: 73645, dtype: object

# %%
df[df["param_m"].apply(len) == 3]["param_m"]
# Out:
# Series([], Name: param_m, dtype: object)

# %%
import numpy as np
tmp_df = pd.DataFrame()

def standardize_param_m(x):
    # This includes some heuristics from analyzing the data
    if len(x) == 3:
        return [x[0], x[1], np.nan, x[2], np.nan]
    elif len(x) == 4:
        return [x[0], x[1], x[2], np.nan, x[3]]
    elif len(x) == 5:
        return x
    
tmp_df["param_m"] = df["param_m"].apply(standardize_param_m)

for i in range(5):
    tmp_df[f"param_m_{i}"] = tmp_df["param_m"].apply(lambda x: x[i])

# %% [markdown]
# ### Check the correlation between variables

# %%
df_combined = pd.concat([raw_df, tmp_df], axis=1)

# Compute the correlation matrix
correlation_matrix = df_combined.corr(numeric_only=True)

correlation_matrix
# Out:
#                     id  district_lon  district_lat     price         m  \
# id            1.000000     -0.017327      0.037581  0.131131 -0.003512
# district_lon -0.017327      1.000000     -0.197719 -0.054762  0.000068
# district_lat  0.037581     -0.197719      1.000000  0.029799 -0.001960
# price         0.131131     -0.054762      0.029799  1.000000  0.010126
# m            -0.003512      0.000068     -0.001960  0.010126  1.000000
# price_per_m   0.162168     -0.007933     -0.002545  0.763156 -0.007921
# map_lon       0.000459      0.236529     -0.047385 -0.006982  0.000631
# map_lat       0.018766     -0.048136      0.499927  0.016527 -0.000456
#
#               price_per_m   map_lon   map_lat
# id               0.162168  0.000459  0.018766
# district_lon    -0.007933  0.236529 -0.048136
# district_lat    -0.002545 -0.047385  0.499927
# price            0.763156 -0.006982  0.016527
# m               -0.007921  0.000631 -0.000456
# price_per_m      1.000000 -0.002468 -0.005458
# map_lon         -0.002468  1.000000  0.520687
# map_lat         -0.005458  0.520687  1.000000

# %% [markdown]
# ***IMPORTANT NOTE*** Cleaning / parsing this data (the "m" value in "params") requires too much effort and heuristics.
#
# In this case, some features must be transformed to datetime, and all to numeric, to make this work smoothly. But I get some errors (not difficult to fix, but I should better expend my time on other, more important, tasks).
#
# I get a sense of the features that it could contain, and they may already be extracted in the original dataset.
#
# In the case of new features, since their name or description is not defined, it would introduce non-explainability to the model, and even some leaking (the data may be directly related to the price).
#
# The decision is therefore to not use this data.
# In a practical setting, I would ask what this data contains (although with good cleaning, and checking correlations, this should work.)

# %% [markdown]
# ## Check param_rent

# %%
df["param_rent"]
# Out:
# 0           [price, 110]
# 1              [price, ]
# 2           [price, 168]
# 3        [price, 457.65]
# 4              [price, ]
#               ...
# 73640          [price, ]
# 73641    [price, 352.21]
# 73642       [price, 290]
# 73643          [price, ]
# 73644          [price, ]
# Name: param_rent, Length: 73645, dtype: object

# %%
# easy to correct:
df["param_rent"] = df["param_rent"].apply(lambda x: x[1] if len(x)==2 else np.nan)

# %% [markdown]
# ## Transform each param
# Now that we have that each param has length 1, let's further transform them

# %%
try:
    unique_params.remove("m")
except:
    pass

for param in unique_params:
    try:
        df[f"param_{param}"] = df[f"param_{param}"].apply(lambda x: x[0] if len(x) == 1 else np.nan)
    except:
        pass

df
# Out:
#              id     market         created_at_first               updated_at  \
# 0      58668640  secondary  2019-04-09 16:12:54.000  2019-04-15 18:54:38.000
# 1      58887800  secondary  2019-04-25 17:20:01.000  2019-05-27 11:36:14.000
# 2      55129916  secondary  2018-08-02 16:40:35.000  2021-11-28 01:56:53.000
# 3      60011531  secondary  2019-12-05 12:45:49.000  2020-01-15 16:05:42.000
# 4      60096194  secondary  2020-01-10 14:53:19.000  2020-02-13 15:25:07.000
# ...         ...        ...                      ...                      ...
# 73640  59477668  secondary  2019-07-16 22:38:08.000  2019-10-14 23:01:42.000
# 73641  59479003  secondary  2019-07-17 11:18:30.000  2019-08-07 14:22:54.000
# 73642  59474988  secondary  2019-07-16 13:40:35.000  2019-07-23 00:30:42.000
# 73643  59428272  secondary  2019-07-03 20:50:27.000  2022-06-17 17:14:34.000
# 73644  59437422  secondary  2019-07-05 23:17:45.000  2019-08-04 23:24:06.000
#
#        district_lon  district_lat  \
# 0          16.90502      52.41180
# 1          16.87466      52.41572
# 2          16.90502      52.41180
# 3          16.87466      52.41572
# 4          16.87466      52.41572
# ...             ...           ...
# 73640      16.94080      52.38356
# 73641      16.94080      52.38356
# 73642      16.90590      52.36596
# 73643      16.94080      52.38356
# 73644      16.93625      52.42658
#
#                                                    title  \
# 0               Mieszkanie z potencjałem. Rynek Jeżycki.
# 1                                     Okazja Jeżyce!!!!!
# 2      **Okazja * 60,1m2 * 3 pokoje * poddasze * Jeży...
# 3              Mieszkanie 2-pokojowe, Ogrody, Kampus Uam
# 4                                        Jeżyce 2 pokoje
# ...                                                  ...
# 73640         Poznań - Rataje idealny układ pomieszczeń.
# 73641       2 pokojowe z balkonem RATAJE os. Piastowskie
# 73642  Inwestycyjne 2 niezależne pokoje, do wykończenia.
# 73643  Przestronna kawalerka z dużym tarasem Chartowo...
# 73644  Sprzedam 3 pokojowe mieszkanie, Poznań - Winog...
#
#                                              description  \
# 0      <p>Zapraszam do zakupu mieszkania zlokalizowan...
# 1      <p>Polecam na sprzedaż mieszkanie kawalerka o ...
# 2      <p>  **Przestronne mieszkanie 3 pokojowe * na ...
# 3      <p>Serdecznie zapraszam do zapoznania się z of...
# 4      <p>Polecam na sprzedaż mieszkanie z komórka lo...
# ...                                                  ...
# 73640  <p>Drodzy Państwo,</p>\r\n<p>Zapraszam do zapo...
# 73641  <p>Polecam na sprzedaż mieszkanie 2 pokojowe u...
# 73642  <p>Na sprzedaż przestronne mieszkanie położone...
# 73643  <p>Kontakt w sprawie oferty - Katarzyna Piotro...
# 73644  <p>Sprzedam 3 pokojowe zadbane mieszkanie usyt...
#
#                                                   params     price  ...  \
# 0      price<=>price<br>price<=>260000<br>price[curre...  260000.0  ...
# 1      price<=>price<br>price<=>155000<br>price[curre...  155000.0  ...
# 2      price<=>price<br>price<=>280000<br>price[curre...  280000.0  ...
# 3      price<=>price<br>price<=>339000<br>price[curre...  339000.0  ...
# 4      price<=>price<br>price<=>325000<br>price[curre...  325000.0  ...
# ...                                                  ...       ...  ...
# 73640  price<=>price<br>price<=>347000<br>price[curre...  347000.0  ...
# 73641  price<=>price<br>price<=>299000<br>price[curre...  299000.0  ...
# 73642  price<=>price<br>price<=>270000<br>price[curre...  270000.0  ...
# 73643  price<=>price<br>price<=>229000<br>price[curre...  229000.0  ...
# 73644  price<=>price<br>price<=>399000<br>price[curre...  399000.0  ...
#
#                                 param_building_ownership  \
# 0                                         full_ownership
# 1
# 2                                         full_ownership
# 3                                         full_ownership
# 4
# ...                                                  ...
# 73640                                     full_ownership
# 73641                             co_operative_ownership
# 73642                             co_operative_ownership
# 73643
# 73644  co_operative_ownership_with_a_land_and_mortgag...
#
#                          param_media_types  param_recreational  \
# 0      cable-television<->internet<->phone                 NaN
# 1                                                          NaN
# 2      cable-television<->internet<->phone                 NaN
# 3                                                          NaN
# 4                                                          NaN
# ...                                    ...                 ...
# 73640  cable-television<->internet<->phone                 NaN
# 73641                                    0                 NaN
# 73642                                                      NaN
# 73643                                                      NaN
# 73644          cable-television<->internet                 NaN
#
#        param_location  param_access_types param_rooms_num  \
# 0                 NaN                 NaN               2
# 1                 NaN                 NaN               1
# 2                 NaN                 NaN               3
# 3                 NaN                 NaN               2
# 4                 NaN                 NaN               2
# ...               ...                 ...             ...
# 73640             NaN                 NaN               3
# 73641             NaN                 NaN               2
# 73642             NaN                 NaN               2
# 73643             NaN                 NaN               1
# 73644             NaN                 NaN               3
#
#        param_vicinity_types param_roof_type param_floor_no  \
# 0                       NaN             NaN        floor_3
# 1                       NaN             NaN        floor_4
# 2                       NaN             NaN        floor_4
# 3                       NaN             NaN        floor_1
# 4                       NaN             NaN        floor_3
# ...                     ...             ...            ...
# 73640                   NaN             NaN        floor_2
# 73641                   NaN             NaN        floor_2
# 73642                   NaN             NaN        floor_1
# 73643                   NaN             NaN        floor_6
# 73644                   NaN             NaN        floor_7
#
#                   param_security_types
# 0
# 1
# 2
# 3
# 4
# ...                                ...
# 73640     entryphone<->roller_shutters
# 73641                                0
# 73642
# 73643                       entryphone
# 73644  anti_burglary_door<->entryphone
#
# [73645 rows x 50 columns]

# %%
for param in unique_params:
    df[f"param_{param}"] = df[f"param_{param}"].apply(lambda x : x.split("<->") if isinstance(x, str) else [x])

len_statistics = df[[f"param_{param}" for param in unique_params]].map(len).agg(['min', 'max', 'mean'])
len_statistics.T
# Out:
#                            min  max      mean
# param_market               1.0  1.0  1.000000
# param_floors_num           1.0  1.0  1.000000
# param_roofing              1.0  1.0  1.000000
# param_terrain_area         1.0  1.0  1.000000
# param_rent[currency]       1.0  1.0  1.000000
# param_windows_type         1.0  1.0  1.000000
# param_rent                 1.0  1.0  1.000000
# param_fence_types          1.0  3.0  1.000027
# param_is_bungalow          1.0  1.0  1.000000
# param_extras_types         1.0  8.0  2.321013
# param_price[currency]      1.0  1.0  1.000000
# param_building_floors_num  1.0  1.0  1.000000
# param_garret_type          1.0  1.0  1.000000
# param_remote_services      1.0  1.0  1.000000
# param_price_per_m          1.0  1.0  1.000000
# param_heating_types        1.0  1.0  1.000000
# param_building_material    1.0  1.0  1.000000
# param_build_year           1.0  1.0  1.000000
# param_building_type        1.0  1.0  1.000000
# param_free_from            1.0  1.0  1.000000
# param_equipment_types      1.0  7.0  1.496612
# param_heating              1.0  1.0  1.000000
# param_construction_status  1.0  1.0  1.000000
# param_building_ownership   1.0  1.0  1.000000
# param_media_types          1.0  7.0  1.521705
# param_recreational         1.0  1.0  1.000000
# param_location             1.0  1.0  1.000000
# param_access_types         1.0  2.0  1.000014
# param_rooms_num            1.0  1.0  1.000000
# param_vicinity_types       1.0  2.0  1.000027
# param_roof_type            1.0  1.0  1.000000
# param_floor_no             1.0  1.0  1.000000
# param_security_types       1.0  6.0  1.387711

# %%
len_statistics.loc["max", "param_market"]
# Out:
# 1.0

# %%
for param in unique_params:
    if len_statistics.loc["max", f"param_{param}"] == 1:
        df[f"param_{param}"] = df[f"param_{param}"].apply(lambda x: x[0])

# %%
df
# Out:
#              id     market         created_at_first               updated_at  \
# 0      58668640  secondary  2019-04-09 16:12:54.000  2019-04-15 18:54:38.000
# 1      58887800  secondary  2019-04-25 17:20:01.000  2019-05-27 11:36:14.000
# 2      55129916  secondary  2018-08-02 16:40:35.000  2021-11-28 01:56:53.000
# 3      60011531  secondary  2019-12-05 12:45:49.000  2020-01-15 16:05:42.000
# 4      60096194  secondary  2020-01-10 14:53:19.000  2020-02-13 15:25:07.000
# ...         ...        ...                      ...                      ...
# 73640  59477668  secondary  2019-07-16 22:38:08.000  2019-10-14 23:01:42.000
# 73641  59479003  secondary  2019-07-17 11:18:30.000  2019-08-07 14:22:54.000
# 73642  59474988  secondary  2019-07-16 13:40:35.000  2019-07-23 00:30:42.000
# 73643  59428272  secondary  2019-07-03 20:50:27.000  2022-06-17 17:14:34.000
# 73644  59437422  secondary  2019-07-05 23:17:45.000  2019-08-04 23:24:06.000
#
#        district_lon  district_lat  \
# 0          16.90502      52.41180
# 1          16.87466      52.41572
# 2          16.90502      52.41180
# 3          16.87466      52.41572
# 4          16.87466      52.41572
# ...             ...           ...
# 73640      16.94080      52.38356
# 73641      16.94080      52.38356
# 73642      16.90590      52.36596
# 73643      16.94080      52.38356
# 73644      16.93625      52.42658
#
#                                                    title  \
# 0               Mieszkanie z potencjałem. Rynek Jeżycki.
# 1                                     Okazja Jeżyce!!!!!
# 2      **Okazja * 60,1m2 * 3 pokoje * poddasze * Jeży...
# 3              Mieszkanie 2-pokojowe, Ogrody, Kampus Uam
# 4                                        Jeżyce 2 pokoje
# ...                                                  ...
# 73640         Poznań - Rataje idealny układ pomieszczeń.
# 73641       2 pokojowe z balkonem RATAJE os. Piastowskie
# 73642  Inwestycyjne 2 niezależne pokoje, do wykończenia.
# 73643  Przestronna kawalerka z dużym tarasem Chartowo...
# 73644  Sprzedam 3 pokojowe mieszkanie, Poznań - Winog...
#
#                                              description  \
# 0      <p>Zapraszam do zakupu mieszkania zlokalizowan...
# 1      <p>Polecam na sprzedaż mieszkanie kawalerka o ...
# 2      <p>  **Przestronne mieszkanie 3 pokojowe * na ...
# 3      <p>Serdecznie zapraszam do zapoznania się z of...
# 4      <p>Polecam na sprzedaż mieszkanie z komórka lo...
# ...                                                  ...
# 73640  <p>Drodzy Państwo,</p>\r\n<p>Zapraszam do zapo...
# 73641  <p>Polecam na sprzedaż mieszkanie 2 pokojowe u...
# 73642  <p>Na sprzedaż przestronne mieszkanie położone...
# 73643  <p>Kontakt w sprawie oferty - Katarzyna Piotro...
# 73644  <p>Sprzedam 3 pokojowe zadbane mieszkanie usyt...
#
#                                                   params     price  ...  \
# 0      price<=>price<br>price<=>260000<br>price[curre...  260000.0  ...
# 1      price<=>price<br>price<=>155000<br>price[curre...  155000.0  ...
# 2      price<=>price<br>price<=>280000<br>price[curre...  280000.0  ...
# 3      price<=>price<br>price<=>339000<br>price[curre...  339000.0  ...
# 4      price<=>price<br>price<=>325000<br>price[curre...  325000.0  ...
# ...                                                  ...       ...  ...
# 73640  price<=>price<br>price<=>347000<br>price[curre...  347000.0  ...
# 73641  price<=>price<br>price<=>299000<br>price[curre...  299000.0  ...
# 73642  price<=>price<br>price<=>270000<br>price[curre...  270000.0  ...
# 73643  price<=>price<br>price<=>229000<br>price[curre...  229000.0  ...
# 73644  price<=>price<br>price<=>399000<br>price[curre...  399000.0  ...
#
#                                 param_building_ownership  \
# 0                                         full_ownership
# 1
# 2                                         full_ownership
# 3                                         full_ownership
# 4
# ...                                                  ...
# 73640                                     full_ownership
# 73641                             co_operative_ownership
# 73642                             co_operative_ownership
# 73643
# 73644  co_operative_ownership_with_a_land_and_mortgag...
#
#                          param_media_types  param_recreational  \
# 0      [cable-television, internet, phone]                 NaN
# 1                                       []                 NaN
# 2      [cable-television, internet, phone]                 NaN
# 3                                       []                 NaN
# 4                                       []                 NaN
# ...                                    ...                 ...
# 73640  [cable-television, internet, phone]                 NaN
# 73641                                  [0]                 NaN
# 73642                                   []                 NaN
# 73643                                   []                 NaN
# 73644         [cable-television, internet]                 NaN
#
#        param_location  param_access_types param_rooms_num  \
# 0                 NaN               [nan]               2
# 1                 NaN               [nan]               1
# 2                 NaN               [nan]               3
# 3                 NaN               [nan]               2
# 4                 NaN               [nan]               2
# ...               ...                 ...             ...
# 73640             NaN               [nan]               3
# 73641             NaN               [nan]               2
# 73642             NaN               [nan]               2
# 73643             NaN               [nan]               1
# 73644             NaN               [nan]               3
#
#        param_vicinity_types param_roof_type param_floor_no  \
# 0                     [nan]             NaN        floor_3
# 1                     [nan]             NaN        floor_4
# 2                     [nan]             NaN        floor_4
# 3                     [nan]             NaN        floor_1
# 4                     [nan]             NaN        floor_3
# ...                     ...             ...            ...
# 73640                 [nan]             NaN        floor_2
# 73641                 [nan]             NaN        floor_2
# 73642                 [nan]             NaN        floor_1
# 73643                 [nan]             NaN        floor_6
# 73644                 [nan]             NaN        floor_7
#
#                    param_security_types
# 0                                    []
# 1                                    []
# 2                                    []
# 3                                    []
# 4                                    []
# ...                                 ...
# 73640     [entryphone, roller_shutters]
# 73641                               [0]
# 73642                                []
# 73643                      [entryphone]
# 73644  [anti_burglary_door, entryphone]
#
# [73645 rows x 50 columns]

# %% [markdown]
# ### One-hot encode the other variables

# %%
dfs_to_concat = [df]

one_hot_columns = []

for param in unique_params:
    if len_statistics.loc["max", f"param_{param}"] > 1:
        df_exploded = df.explode(f"param_{param}")
        one_hot_df = pd.get_dummies(df_exploded[f"param_{param}"], prefix=f"param_{param}")
        one_hot_df.drop(columns=[f"param_{param}_0", f"param_{param}_"], inplace=True, errors="ignore")

        one_hot_columns.append(one_hot_df.columns)
        
        # Add the one-hot encoded dataframe to the list
        dfs_to_concat.append(one_hot_df)

# Concatenate all dataframes at once
df = pd.concat(dfs_to_concat, axis=0)

# %%
df
# Out:
#                id     market         created_at_first  \
# 0      58668640.0  secondary  2019-04-09 16:12:54.000
# 1      58887800.0  secondary  2019-04-25 17:20:01.000
# 2      55129916.0  secondary  2018-08-02 16:40:35.000
# 3      60011531.0  secondary  2019-12-05 12:45:49.000
# 4      60096194.0  secondary  2020-01-10 14:53:19.000
# ...           ...        ...                      ...
# 73641         NaN        NaN                      NaN
# 73642         NaN        NaN                      NaN
# 73643         NaN        NaN                      NaN
# 73644         NaN        NaN                      NaN
# 73644         NaN        NaN                      NaN
#
#                     updated_at  district_lon  district_lat  \
# 0      2019-04-15 18:54:38.000      16.90502      52.41180
# 1      2019-05-27 11:36:14.000      16.87466      52.41572
# 2      2021-11-28 01:56:53.000      16.90502      52.41180
# 3      2020-01-15 16:05:42.000      16.87466      52.41572
# 4      2020-02-13 15:25:07.000      16.87466      52.41572
# ...                        ...           ...           ...
# 73641                      NaN           NaN           NaN
# 73642                      NaN           NaN           NaN
# 73643                      NaN           NaN           NaN
# 73644                      NaN           NaN           NaN
# 73644                      NaN           NaN           NaN
#
#                                                    title  \
# 0               Mieszkanie z potencjałem. Rynek Jeżycki.
# 1                                     Okazja Jeżyce!!!!!
# 2      **Okazja * 60,1m2 * 3 pokoje * poddasze * Jeży...
# 3              Mieszkanie 2-pokojowe, Ogrody, Kampus Uam
# 4                                        Jeżyce 2 pokoje
# ...                                                  ...
# 73641                                                NaN
# 73642                                                NaN
# 73643                                                NaN
# 73644                                                NaN
# 73644                                                NaN
#
#                                              description  \
# 0      <p>Zapraszam do zakupu mieszkania zlokalizowan...
# 1      <p>Polecam na sprzedaż mieszkanie kawalerka o ...
# 2      <p>  **Przestronne mieszkanie 3 pokojowe * na ...
# 3      <p>Serdecznie zapraszam do zapoznania się z of...
# 4      <p>Polecam na sprzedaż mieszkanie z komórka lo...
# ...                                                  ...
# 73641                                                NaN
# 73642                                                NaN
# 73643                                                NaN
# 73644                                                NaN
# 73644                                                NaN
#
#                                                   params     price  ...  \
# 0      price<=>price<br>price<=>260000<br>price[curre...  260000.0  ...
# 1      price<=>price<br>price<=>155000<br>price[curre...  155000.0  ...
# 2      price<=>price<br>price<=>280000<br>price[curre...  280000.0  ...
# 3      price<=>price<br>price<=>339000<br>price[curre...  339000.0  ...
# 4      price<=>price<br>price<=>325000<br>price[curre...  325000.0  ...
# ...                                                  ...       ...  ...
# 73641                                                NaN       NaN  ...
# 73642                                                NaN       NaN  ...
# 73643                                                NaN       NaN  ...
# 73644                                                NaN       NaN  ...
# 73644                                                NaN       NaN  ...
#
#       param_access_types_asphalt  param_access_types_hard_surfaced  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
# ...                          ...                               ...
# 73641                        NaN                               NaN
# 73642                        NaN                               NaN
# 73643                        NaN                               NaN
# 73644                        NaN                               NaN
# 73644                        NaN                               NaN
#
#        param_vicinity_types_forest  param_vicinity_types_lake  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 73641                          NaN                        NaN
# 73642                          NaN                        NaN
# 73643                          NaN                        NaN
# 73644                          NaN                        NaN
# 73644                          NaN                        NaN
#
#        param_security_types_alarm param_security_types_anti_burglary_door  \
# 0                             NaN                                     NaN
# 1                             NaN                                     NaN
# 2                             NaN                                     NaN
# 3                             NaN                                     NaN
# 4                             NaN                                     NaN
# ...                           ...                                     ...
# 73641                       False                                   False
# 73642                       False                                   False
# 73643                       False                                   False
# 73644                       False                                    True
# 73644                       False                                   False
#
#        param_security_types_closed_area param_security_types_entryphone  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
# ...                                 ...                             ...
# 73641                             False                           False
# 73642                             False                           False
# 73643                             False                            True
# 73644                             False                           False
# 73644                             False                            True
#
#       param_security_types_monitoring param_security_types_roller_shutters
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# ...                               ...                                  ...
# 73641                           False                                False
# 73642                           False                                False
# 73643                           False                                False
# 73644                           False                                False
# 73644                           False                                False
#
# [789998 rows x 90 columns]

# %% [markdown]
# ## Get the number of positive one-hots

# %%
one_hot_columns = [o.values.tolist() for o in one_hot_columns]

# %% [markdown]
# Flatten the list

# %%
one_hot_columns = [item for sublist in one_hot_columns for item in sublist]

# %%
column_sums = one_hot_df.sum()

sorted_column_sums = column_sums.sort_values(ascending=True)
sorted_column_sums
# Out:
# param_security_types_alarm                  1109
# param_security_types_roller_shutters        2405
# param_security_types_closed_area            8540
# param_security_types_monitoring             9577
# param_security_types_anti_burglary_door    10744
# param_security_types_entryphone            27902
# dtype: int64

# %%
# We can drop columns with less than 20 positive entries
filtered_columns = sorted_column_sums[sorted_column_sums < 20].index.tolist()
print(len(df.columns))
df.drop(columns=filtered_columns, inplace=True, errors="ignore")
print(len(df.columns))
# Out:
# 90
# 90

# %% [markdown]
# ### One-hot-encode the other features

# %%
unique_values = df[[f"param_{param}" for param in unique_params if len_statistics.loc["max", f"param_{param}"] == 1]].nunique()
unique_values
# Out:
# param_market                    2
# param_floors_num               31
# param_roofing                   3
# param_terrain_area              9
# param_rent[currency]            4
# param_windows_type              4
# param_rent                      9
# param_is_bungalow               0
# param_price[currency]           2
# param_building_floors_num      29
# param_garret_type               3
# param_remote_services           2
# param_price_per_m              10
# param_heating_types             2
# param_building_material        11
# param_build_year              193
# param_building_type            10
# param_free_from              1388
# param_heating                   7
# param_construction_status       4
# param_building_ownership        5
# param_recreational              2
# param_location                  2
# param_rooms_num                11
# param_roof_type                 3
# param_floor_no                 15
# dtype: int64

# %%
one_hot_numeric_columns = ["param_rooms_num", "param_building_floors_num", "param_floors_num", "param_free_from", "param_floor_no", "param_terrain_area", "param_rent"]

for column in [f"param_{param}" for param in unique_params if len_statistics.loc["max", f"param_{param}"] == 1]:
    if column not in one_hot_numeric_columns:
        print(column)
# Out:
# param_market
# param_roofing
# param_rent[currency]
# param_windows_type
# param_is_bungalow
# param_price[currency]
# param_garret_type
# param_remote_services
# param_price_per_m
# param_heating_types
# param_building_material
# param_build_year
# param_building_type
# param_heating
# param_construction_status
# param_building_ownership
# param_recreational
# param_location
# param_roof_type

# %%
df["param_rent[currency]"].value_counts()
# Out:
# param_rent[currency]
# PLN    63176
#        10467
# EUR        1
# USD        1
# Name: count, dtype: int64

# %%
df["param_floors_num"].value_counts()
# Out:
# param_floors_num
# 4             22720
# 5             13865
#                7649
# 3              6845
# 6              4550
# 10             3527
# 2              3441
# 8              2443
# 11             1893
# 7              1613
# 16             1134
# 1              1017
# 12              874
# 15              664
# 14              461
# 9               361
# 13              274
# 17              201
# 18               69
# 22               14
# 21                7
# 19                5
# 20                5
# two_floors        4
# one_floor         3
# 45                1
# 534810500         1
# 64                1
# 24                1
# 65                1
# 166               1
# Name: count, dtype: int64

# %%
df["param_price_per_m"].dropna().unique()
# Out:
# array(['7833.33', '5177.51', '4250', '6122.81', '5403.23', '9019.03',
#        '7231.99', '4800', '8375.31', '8125'], dtype=object)
